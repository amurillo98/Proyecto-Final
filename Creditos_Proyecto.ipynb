# %% [markdown]
# <a href="https://colab.research.google.com/github/amurillo98/Proyecto-Final/blob/main/Creditos_Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
creditos_proyecto = pd.read_csv("/content/drive/My Drive/Colab Notebooks/creditos_historicos.csv",sep=",")
creditos_proyecto
# Out:
# <ipython-input-5-4542b2df4d34>:1: DtypeWarning: Columns (13,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   creditos_proyecto = pd.read_csv("/content/drive/My Drive/Colab Notebooks/creditos_historicos.csv",sep=",")
#          id_cliente loan_status  loan_amnt  installment        term  \
# 0                 0     Current       2500        84.92   36 months
# 1                 1     Current      30000       777.23   60 months
# 2                 2     Current       5000       180.69   36 months
# 3                 3     Current       4000       146.51   36 months
# 4                 4     Current      30000       731.78   60 months
# ...             ...         ...        ...          ...         ...
# 2260663     2260663     Current      12000       279.72   60 months
# 2260664     2260664  Fully Paid      12000       358.01   60 months
# 2260665     2260665     Current      10000       332.10   36 months
# ...

# %% [markdown]
# **DATA** **QUALITY**

# %%
creditos_proyecto['id_cliente'].value_counts()
# Out:
# id_cliente
# 0          1
# 1507114    1
# 1507108    1
# 1507109    1
# 1507110    1
#           ..
# 753550     1
# 753549     1
# 753548     1
# 753547     1
# 2260667    1
# Name: count, Length: 2260668, dtype: int64

# %% [markdown]
# No existen id_cliente duplicados

# %%
creditos_proyecto[creditos_proyecto.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id_cliente, loan_status, loan_amnt, installment, term, emp_title, emp_length, home_ownership, annual_inc, verification_status, purpose, addr_state, delinq_2yrs, next_pymnt_d, earliest_cr_line, mths_since_last_delinq, total_pymnt, recoveries, collection_recovery_fee, last_pymnt_d, settlement_status, application_type, tot_hi_cred_lim]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# No existen registros duplicados

# %%
creditos_proyecto.isnull().sum()
# Out:
# id_cliente                       0
# loan_status                      0
# loan_amnt                        0
# installment                      0
# term                             0
# emp_title                   166969
# emp_length                  146907
# home_ownership                   0
# annual_inc                       4
# verification_status              0
# purpose                          0
# addr_state                       0
# delinq_2yrs                     29
# next_pymnt_d               1303607
# earliest_cr_line                29
# mths_since_last_delinq     1158502
# total_pymnt                      0
# recoveries                       0
# collection_recovery_fee          0
# last_pymnt_d                  2426
# settlement_status          2227612
# application_type                 0
# tot_hi_cred_lim              70276
# dtype: int64

# %% [markdown]
# Definición mal pagador = loan status que tenga charged off / late (31 - 120 days) y los que tengan default y late (16-30 days) que tengan más de 3 veces vencidos en dos últimos años y que se haya vencido en el último año.
